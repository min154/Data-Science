# %% [markdown]
# # 3장 : 시카고 샌드위치 맛집 분석
# ### 8월 19일 스터디
# #####
# ## 3-1. 웹 데이터를 가져오는 Beautiful Soup 익히기

# %%
from bs4 import BeautifulSoup

# %%
#open 명령으로 html 파일 읽어오기
page = open("../data/03. test_first.html", 'r').read()
soup = BeautifulSoup(page, 'html.parser') #parser 꼭 써줘야한다고 함
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>,
#  '\n',
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>,
#  '\n']

# %%
list(html.children)[0]
# Out:
# '\n'

# %%
body = list(html.children)[3]
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
list(body.children)
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>,
#  '\n']

# %%
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# Out:
# [<div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>]

# %%
soup.find_all('p', class_ = "outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(class_ = "outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id = "first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.head.next_sibling
# Out:
# '\n'

# %%
soup.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
body.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
body.p.next_sibling.next_sibling
# Out:
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>

# %%
body.p.next_sibling
# Out:
# '\n'

# %%
for each_tag in soup.find_all('p'):
    print(each_tag.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
body.get_text()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
links = soup.find_all('a')
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
for each in links:
    href = each['href']
    text = each.string
    print(text + ' -> ' + href)
# Out:
# PinkWink -> http://www.pinkwink.kr
# Python -> https://www.python.org

# %% [markdown]
# #####
# #####
# ## 3-2. 크롬 개발자 도구를 이용해서 원하는 태그 찾기

# %%
from urllib.request import urlopen

# %%
url = "https://finance.naver.com/marketindex/"
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20220816134009/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20220816134009/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
soup.find_all('span', 'value')[0].string
# Out:
# '1,323.50'

# %% [markdown]
# #####
# #####
# ## 3-3. 실전 : 시카고 샌드위치 맛집 소개 사이트에 접근하기

# %%
#원래 코드를 사용하면 웹 크롤링 시에 불법 크롤링을 방지하지 위해 서버의 시큐리티가 작동하여 에러 발생

from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen

url_base = 'http://www.chicagomag.com'
url_sub = '/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'
url = url_base + url_sub

req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(req)
soup = BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>The 50 Best Sandwiches in Chicago – Chicago Magazine</title>
# <style type="text/css">
# 					.heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# 							background-color: #000!important;
# 				background: #000!important;
# 							color: #fff;
# 						border-width: 0px;
# 			border-style: solid;
# ...

# %%
soup.find_all('div')
# Out:
# [<div id="app"></div>]

# %%
print(soup.find_all('div', 'sammy'))
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">3</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
# Xoco<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">4</div>
# ...

# %%
#시카고 샌드위치 맛집 Top50이므로
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
print(soup.find_all('div', 'sammy')[0])
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %% [markdown]
# #####
# #####
# ## 3-4. 접근한 웹 페이지에서 원하는 데이터 추출하고 정리하기

# %%
tmp_one = soup.find_all('div', 'sammy')[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
tmp_one.find(class_ = 'sammyRank')
# Out:
# <div class="sammyRank">1</div>

# %%
tmp_one.find(class_ = 'sammyRank').get_text()
# Out:
# '1'

# %%
#메뉴 이름과 가게 이름
tmp_one.find(class_ = 'sammyListing').get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
#a라는 태그에서 href 정보 가져오기
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
import re

tmp_string = tmp_one.find(class_ = 'sammyListing').get_text()

re.split(('\n|\r\n'), tmp_string) #or의 의미를 가지는 메타문자 |

print(re.split(('\n|\r\n'), tmp_string)[0])
print(re.split(('\n|\r\n'), tmp_string)[1])
# Out:
# BLT
# Old Oak Tap

# %%
from urllib.parse import urljoin 

rank = []
main_menu = []
cafe_name = []
url_add = []

list_soup = soup.find_all('div', 'sammy')

for item in list_soup:
    rank.append(item.find(class_ = 'sammyRank').get_text())
    
    tmp_string = item.find(class_ = 'sammyListing').get_text()
    
    main_menu.append(re.split(('\n|\r\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n|\r\n'), tmp_string)[1])
    
    url_add.append(urljoin(url_base, item.find('a')['href']))

# %%
rank[:5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
main_menu[:5]
# Out:
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %%
url_add[:5]
# Out:
# ['http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
len(rank), len(main_menu), len(cafe_name), len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

data = {'Rank' : rank, 'Menu' : main_menu, 'Cafe' : cafe_name, 'URL' : url_add}
df = pd.DataFrame(data)
df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df = pd.DataFrame(data, columns = ['Rank', 'Cafe', 'Menu', 'URL'])
df.head(5)
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df.to_csv('../data/03. best_sandwiches_list_chicago.csv', sep = ',', encoding = 'UTF-8')

# %% [markdown]
# #####
# #####
# ## 3-5. 다수의 웹 페이지에 자동으로 접근해서 원하는 정보 가져오기

# %%
df = pd.read_csv('../data/03. best_sandwiches_list_chicago.csv', index_col = 0)
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df['URL'][0]
# Out:
# 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
#원래 코드를 사용하면 웹 크롤링 시에 불법 크롤링을 방지하지 위해 서버의 시큐리티가 작동하여 에러 발생

url1 = Request(df['URL'][0], headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(url1)
soup_tmp = BeautifulSoup(html, "html.parser")
soup_tmp
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>1. Old Oak Tap BLT – Chicago Magazine</title>
# <style type="text/css">
# 					.heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# 							background-color: #000!important;
# 				background: #000!important;
# 							color: #fff;
# 						border-width: 0px;
# 			border-style: solid;
# 			border-color: transparent;
# 		}
# ...

# %%
print(soup_tmp.find('p', 'addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
price_tmp = soup_tmp.find('p', 'addy').get_text()
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
price_tmp.split()
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
#가격 정보
price_tmp.split()[0]
# Out:
# '$10.'

# %%
price_tmp.split()[0][:-1]
# Out:
# '$10'

# %%
' '.join(price_tmp.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %%
price = []
address = []

for n in df.index[:3]:
    url = Request(df['URL'][n], headers={'User-Agent': 'Mozilla/5.0'})
    html = urlopen(url)
    soup_tmp = BeautifulSoup(html, 'lxml')
    
    gettings = soup_tmp.find('p', 'addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))

# %%
price
# Out:
# ['$10', '$9', '$9.50']

# %%
address
# Out:
# ['2109 W. Chicago Ave.,', '800 W. Randolph St.,', '445 N. Clark St.,']

# %% [markdown]
# #####
# #####
# ## 3-7. 상태 진행바까지 적용하고 다시 샌드위치 페이지 50개에 접근하기

# %%
#원래 코드를 사용하면 웹 크롤링 시에 불법 크롤링을 방지하지 위해 서버의 시큐리티가 작동하여 에러 발생

from tqdm import tqdm_notebook

price = []
address = []

for n in tqdm_notebook(df.index):
    url = Request(df['URL'][n], headers={'User-Agent': 'Mozilla/5.0'})
    html = urlopen(url)
    soup_tmp = BeautifulSoup(html, 'lxml')
    
    gettings = soup_tmp.find('p', 'addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
# Out:
# C:\Users\장민영\AppData\Local\Temp/ipykernel_15944/4237056807.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(df.index):
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# #####
# #####
# ## 3-8. 50개 웹 페이지에 대한 정보 가져오기

# %%
price
# Out:
# ['$10',
#  '$9',
#  '$9.50',
#  '$9.40',
#  '$10',
#  '$7.25',
#  '$16',
#  '$10',
#  '$9',
#  '$17',
#  '$11',
#  '$5.49',
#  '$14',
#  '$10',
#  '$13',
#  '$4.50',
#  '$11.95',
#  '$11.50',
#  '$6.25',
#  '$15',
#  '$5',
#  '$6',
#  '$8',
#  '$5.99',
#  '$7.52',
#  '$11.95',
#  '$7.50',
#  '$12.95',
#  '$7',
#  '$21',
#  '$9.79',
#  '$9.75',
#  '$13',
#  '$7.95',
#  '$9',
#  '$9',
#  '$8',
#  '$8',
#  '$7',
#  '$6',
#  '$7.25',
#  '$11',
#  '$6',
#  '$9',
#  '$5.49',
#  '$8',
#  '$6.50',
#  '$7.50',
#  '$8.75',
#  '$6.85']

# %%
address
# Out:
# ['2109 W. Chicago Ave.,',
#  '800 W. Randolph St.,',
#  '445 N. Clark St.,',
#  '914 Noyes St., Evanston,',
#  '825 W. Fulton Mkt.,',
#  '100 E. Walton',
#  '1639 S. Wabash Ave.,',
#  '2211 W. North Ave.,',
#  '3619 W. North Ave.,',
#  '3267 S. Halsted St.,',
#  '2537 N. Kedzie Blvd.,',
#  'Multiple',
#  '3124 N. Broadway,',
#  '3455 N. Southport Ave.,',
#  '2657 N. Kedzie Ave.,',
#  '1120 W. Grand Ave.,',
#  '1141 S. Jefferson St.,',
#  '333 E. Benton Pl.,',
#  '1411 N. Wells St.,',
#  '1747 N. Damen Ave.,',
#  '3209 W. Irving Park',
#  'Multiple',
#  '5347 N. Clark St.,',
#  '2954 W. Irving Park Rd.,',
#  'Multiple',
#  '191 Skokie Valley Rd., Highland Park,',
#  'Multiple',
#  '1818 W. Wilson Ave.,',
#  '2517 W. Division St.,',
#  '218 W. Kinzie',
#  'Multiple',
#  '1547 N. Wells St.,',
#  '415 N. Milwaukee Ave.,',
#  '1840 N. Damen Ave.,',
#  '1220 W. Webster Ave.,',
#  '5357 N. Ashland Ave.,',
#  '1834 W. Montrose Ave.,',
#  '615 N. State St.,',
#  'Multiple',
# ...

# %%
len(price), len(address), len(df)
# Out:
# (50, 50, 50)

# %%
df['Price'] = price
df['Address'] = address

df = df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price', 'Address']]
df.set_index('Rank', inplace = True)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
df.to_csv('../data/03. best_sandwiches_list_chicago2.csv', sep = ',', encoding = 'UTF-8')

# %% [markdown]
# #####
# #####
# ## 3-9. 맛집 위치를 지도에 표기하기

# %%
import folium
import pandas as pd
import googlemaps
import numpy as np

# %%
df = pd.read_csv('../data/03. best_sandwiches_list_chicago2.csv', index_col = 0)
df.head(5)
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
gmaps_key = "AIzaSyD-sbWPquI23OP2c-HC93RZ_1xpPOeRb5M"
gmaps = googlemaps.Client(key = gmaps_key)

# %%
lat = []
lng = []

for n in tqdm_notebook(df.index):
    if df['Address'][n] != 'Multiple':
        target_name = df['Address'][n]+', '+'Chicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
        
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# C:\Users\장민영\AppData\Local\Temp/ipykernel_15944/307326373.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(df.index):
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
df['lat'] = lat
df['lng'] = lng
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address        lat        lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895558 -87.679967
# 2         800 W. Randolph St.,  41.884639 -87.647590
# 3            445 N. Clark St.,  41.890523 -87.630783
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# 5          825 W. Fulton Mkt.,  41.886604 -87.648536

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], 
                                      zoom_start=11)
folium.Marker([df['lat'].mean(), df['lng'].mean()], 
                                      popup='center').add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], 
                     zoom_start=11)

for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], 
                                      popup=df['Cafe'][n]).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #####
# #####
# ## 3-10. 네이버 영화 평점 기준 영화의 평점 변화 확인하기

# %%
from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20220817'
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20220817" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
#원래 코드를 사용하면 웹 크롤링 시에 불법 크롤링을 방지하지 위해 서버의 시큐리티가 작동하여 에러 발생

from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20220817'

req = Request(page, headers={'User-Agent': 'Mozilla/5.0'})
page = urlopen(req)
soup = BeautifulSoup(page, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20220817" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=81888" title="탑건: 매버릭">탑건: 매버릭</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=217719" title="명탐정 코난: 할로윈의 신부">명탐정 코난: 할로윈의 신부</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=192608" title="범죄도시2">범죄도시2</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=150376" title="나, 다니엘 블레이크">나, 다니엘 블레이크</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=213733" title="극장판 주술회전 0">극장판 주술회전 0</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=152160" title="킹 오브 프리즘">킹 오브 프리즘</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=201073" title="코다">코다</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=164290" title="킹 오브 프리즘 프라이드 더 히어로">킹 오브 프리즘 프라이드 더 히어로</a>
#  </div>,
#  <div class="tit5">
# ...

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '탑건: 매버릭'

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.77'

# %%
date = pd.date_range('2022-5-1', periods = 100, freq = 'D')
date
# Out:
# DatetimeIndex(['2022-05-01', '2022-05-02', '2022-05-03', '2022-05-04',
#                '2022-05-05', '2022-05-06', '2022-05-07', '2022-05-08',
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-14', '2022-05-15', '2022-05-16',
#                '2022-05-17', '2022-05-18', '2022-05-19', '2022-05-20',
#                '2022-05-21', '2022-05-22', '2022-05-23', '2022-05-24',
#                '2022-05-25', '2022-05-26', '2022-05-27', '2022-05-28',
#                '2022-05-29', '2022-05-30', '2022-05-31', '2022-06-01',
#                '2022-06-02', '2022-06-03', '2022-06-04', '2022-06-05',
#                '2022-06-06', '2022-06-07', '2022-06-08', '2022-06-09',
#                '2022-06-10', '2022-06-11', '2022-06-12', '2022-06-13',
#                '2022-06-14', '2022-06-15', '2022-06-16', '2022-06-17',
#                '2022-06-18', '2022-06-19', '2022-06-20', '2022-06-21',
# ...

# %%
#원래 코드를 사용하면 웹 크롤링 시에 불법 크롤링을 방지하지 위해 서버의 시큐리티가 작동하여 에러 발생

import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "https://movie.naver.com/" + \
                                    "movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    
    response = urlopen(html.format(date = urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# Out:
# C:\Users\장민영\AppData\Local\Temp/ipykernel_15944/3368387621.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for today in tqdm_notebook(date):
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#아래 pivot table 생성 과정에서 point가 문자열이라 sum으로 합계를 구하지 못해 결과가 다르게 나옴
#따라서 map 함수를 이용하여 point에 해당하는 리스트 전체를 숫자인 float 형태로 변환
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':list(map(float, movie_point))})
movie.head()
# Out:
#         date               name  point
# 0 2022-05-01               씽2게더   9.39
# 1 2022-05-01             시네마 천국   9.33
# 2 2022-05-01  극장판 귀멸의 칼날: 무한열차편   9.27
# 3 2022-05-01         극장판 주술회전 0   9.26
# 4 2022-05-01          피아니스트의 전설   9.25

# %%
#깃허브 오류 수정방법
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':list(map(float, movie_point))})
movie['point'] = movie['point'].astype(float)
movie.head()
# Out:
#         date               name  point
# 0 2022-05-01               씽2게더   9.39
# 1 2022-05-01             시네마 천국   9.33
# 2 2022-05-01  극장판 귀멸의 칼날: 무한열차편   9.27
# 3 2022-05-01         극장판 주술회전 0   9.26
# 4 2022-05-01          피아니스트의 전설   9.25

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index = ['name'], aggfunc = np.sum)
movie_best = movie_unique.sort_values(by = 'point', ascending = False)
movie_best.head()
# Out:
#              point
# name
# 극장판 주술회전 0  924.83
# 코다          912.89
# 중경삼림        880.93
# 범죄도시2       786.02
# 드라이브 마이 카   714.87

# %%
tmp = movie.query('name == ["마녀(魔女) Part2. The Other One"]')
tmp
# Out:
#            date                         name  point
# 1728 2022-06-15  마녀(魔女) Part2. The Other One   7.39
# 1774 2022-06-16  마녀(魔女) Part2. The Other One   6.91
# 1819 2022-06-17  마녀(魔女) Part2. The Other One   6.96
# 1865 2022-06-18  마녀(魔女) Part2. The Other One   6.79
# 1909 2022-06-19  마녀(魔女) Part2. The Other One   6.70
# 1954 2022-06-20  마녀(魔女) Part2. The Other One   6.67
# 2003 2022-06-21  마녀(魔女) Part2. The Other One   6.67
# 2050 2022-06-22  마녀(魔女) Part2. The Other One   6.68
# 2099 2022-06-23  마녀(魔女) Part2. The Other One   6.67
# 2151 2022-06-24  마녀(魔女) Part2. The Other One   6.66
# 2196 2022-06-25  마녀(魔女) Part2. The Other One   6.66
# 2236 2022-06-26  마녀(魔女) Part2. The Other One   6.65
# 2281 2022-06-27  마녀(魔女) Part2. The Other One   6.65
# 2327 2022-06-28  마녀(魔女) Part2. The Other One   6.66
# 2373 2022-06-29  마녀(魔女) Part2. The Other One   6.67
# 2415 2022-06-30  마녀(魔女) Part2. The Other One   6.67
# 2456 2022-07-01  마녀(魔女) Part2. The Other One   6.68
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize = (12, 8))

plt.plot(tmp['date'], tmp['point'])
plt.legend(loc = 'best')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #####
# #####
# ## 3-11. 영화별 날짜 변화에 따른 평점 변화 확인하기

# %%
movie_pivot = pd.pivot_table(movie, index = ['date'], columns = ['name'], values = ['point'])
movie_pivot.head()
# Out:
#                    point                                                    \
# name       개를 훔치는 완벽한 방법 걸어도 걸어도 경계선 고스트 스토리  공기살인 광대: 소리꾼 군도:민란의 시대    귀향
# date
# 2022-05-01           9.0     NaN NaN     NaN  8.61     NaN       NaN  8.67
# 2022-05-02           9.0     NaN NaN     NaN  8.61     NaN       NaN  8.67
# 2022-05-03           9.0     NaN NaN     NaN  8.61     NaN       NaN  8.67
# 2022-05-04           9.0     NaN NaN     NaN  8.59     NaN       NaN  8.67
# 2022-05-05           9.0     NaN NaN     NaN  8.58     NaN       NaN  8.67
#
#                        ...                                              \
# name        그녀 그대가 조국  ... 한산: 용의 출현 한여름의 판타지아 해운대 해피 투게더 헤어질 결심 헤이트풀8
# date                   ...
# 2022-05-01 NaN    NaN  ...       NaN       7.8 NaN    NaN    NaN   NaN
# 2022-05-02 NaN    NaN  ...       NaN       7.8 NaN    NaN    NaN   NaN
# 2022-05-03 NaN    NaN  ...       NaN       7.8 NaN    NaN    NaN   NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()
movie_pivot.head()
# Out:
# name        개를 훔치는 완벽한 방법  걸어도 걸어도  경계선  고스트 스토리  공기살인  광대: 소리꾼  군도:민란의 시대  \
# date
# 2022-05-01            9.0      NaN  NaN      NaN  8.61      NaN        NaN
# 2022-05-02            9.0      NaN  NaN      NaN  8.61      NaN        NaN
# 2022-05-03            9.0      NaN  NaN      NaN  8.61      NaN        NaN
# 2022-05-04            9.0      NaN  NaN      NaN  8.59      NaN        NaN
# 2022-05-05            9.0      NaN  NaN      NaN  8.58      NaN        NaN
#
# name          귀향  그녀  그대가 조국  ...  한산: 용의 출현  한여름의 판타지아  해운대  해피 투게더  헤어질 결심  \
# date                          ...
# 2022-05-01  8.67 NaN     NaN  ...        NaN        7.8  NaN     NaN     NaN
# 2022-05-02  8.67 NaN     NaN  ...        NaN        7.8  NaN     NaN     NaN
# 2022-05-03  8.67 NaN     NaN  ...        NaN        7.8  NaN     NaN     NaN
# 2022-05-04  8.67 NaN     NaN  ...        NaN        7.8  NaN     NaN     NaN
# 2022-05-05  8.67 NaN     NaN  ...        NaN        7.8  NaN     NaN     NaN
#
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
movie_pivot.plot(y = ['헤어질 결심', '토르: 러브 앤 썬더', '탑건: 매버릭', '마녀(魔女) Part2. The Other One'], 
                 figsize = (12, 6))
plt.legend(loc = 'best')
plt.grid()
plt.show()
